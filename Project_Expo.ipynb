# %% [markdown]
# <a href="https://colab.research.google.com/github/sau-anik-9/Traffic-Detection/blob/main/Project_Expo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("traffic.csv")

# %%
data
# Out:
#                   DateTime  Junction  Vehicles           ID
# 0      2015-11-01 00:00:00         1        15  20151101001
# 1      2015-11-01 01:00:00         1        13  20151101011
# 2      2015-11-01 02:00:00         1        10  20151101021
# 3      2015-11-01 03:00:00         1         7  20151101031
# 4      2015-11-01 04:00:00         1         9  20151101041
# ...                    ...       ...       ...          ...
# 48115  2017-06-30 19:00:00         4        11  20170630194
# 48116  2017-06-30 20:00:00         4        30  20170630204
# 48117  2017-06-30 21:00:00         4        16  20170630214
# 48118  2017-06-30 22:00:00         4        22  20170630224
# 48119  2017-06-30 23:00:00         4        12  20170630234
#
# [48120 rows x 4 columns]

# %%
data.size
# Out:
# 192480

# %%
data.shape
# Out:
# (48120, 4)

# %%
data.describe()
# Out:
#            Junction      Vehicles            ID
# count  48120.000000  48120.000000  4.812000e+04
# mean       2.180549     22.791334  2.016330e+10
# std        0.966955     20.750063  5.944854e+06
# min        1.000000      1.000000  2.015110e+10
# 25%        1.000000      9.000000  2.016042e+10
# 50%        2.000000     15.000000  2.016093e+10
# 75%        3.000000     29.000000  2.017023e+10
# max        4.000000    180.000000  2.017063e+10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  object
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
#  3   ID        48120 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
data.drop('ID',axis=1,inplace=True) # The values for ID is not needed

# %%
data
# Out:
#                   DateTime  Junction  Vehicles
# 0      2015-11-01 00:00:00         1        15
# 1      2015-11-01 01:00:00         1        13
# 2      2015-11-01 02:00:00         1        10
# 3      2015-11-01 03:00:00         1         7
# 4      2015-11-01 04:00:00         1         9
# ...                    ...       ...       ...
# 48115  2017-06-30 19:00:00         4        11
# 48116  2017-06-30 20:00:00         4        30
# 48117  2017-06-30 21:00:00         4        16
# 48118  2017-06-30 22:00:00         4        22
# 48119  2017-06-30 23:00:00         4        12
#
# [48120 rows x 3 columns]

# %%
convert_dict = {'Junction': float}
# Here using astype will return a new dataframe where Junction data have been changed to float
data = data.astype(convert_dict)

# %%
X=data.values
Y=data.iloc[38496:48120,0:3].values

# %%
data_train=pd.DataFrame(X, columns = ['DateTime','Junction','Vehicles'])

# %%
data_test=pd.DataFrame(Y, columns = ['DateTime','Junction','Vehicles'])

# %% [markdown]
# # Lag Features
# Lag features are values at prior timesteps that are considered useful because they are made keeping in mind the assumption that what happened in the past can influence or contain a sort of intrinsic information about the future.

# %%
data_train.head(5)
# Out:
#               DateTime Junction Vehicles
# 0  2015-11-01 00:00:00      1.0       15
# 1  2015-11-01 01:00:00      1.0       13
# 2  2015-11-01 02:00:00      1.0       10
# 3  2015-11-01 03:00:00      1.0        7
# 4  2015-11-01 04:00:00      1.0        9

# %%
# Here pivot method is used to reshape the dataframe organized by Junction Number
train = data_train.pivot(index='DateTime',columns='Junction',values='Vehicles')
train.head(5)
# Out:
# <ipython-input-17-4f8aeadf890d>:2: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   train = data_train.pivot(index='DateTime',columns='Junction',values='Vehicles')
# Junction            1.0 2.0 3.0  4.0
# DateTime
# 2015-11-01 00:00:00  15   6   9  NaN
# 2015-11-01 01:00:00  13   6   7  NaN
# 2015-11-01 02:00:00  10   5   5  NaN
# 2015-11-01 03:00:00   7   6   1  NaN
# 2015-11-01 04:00:00   9   7   2  NaN

# %%
train= train.fillna(0)

# %%
def gen_lag_features(data1,n_in=1,n_out=1,dropnan=True):
    n_vars=data1.shape[1]
    cols,names=list(),list()
    # input sequence (t-n,...t-1)
    for i in range(n_in,0,-1):
        cols.append(data1.shift(i))
        names+=[('Junction %d (H-%d)'%(j+1,i)) for j in range(n_vars)]
    # forecast sequence (t,t+1...t+n)
    for i in range(0,n_out):
        cols.append(data1.shift(-i))
        if i== 0:
            names+=[('Junction %d (H)' % (j+1)) for j in range(n_vars)]
        else:
            names+=[('Junction %d (H+%d)' % (j+1,i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols,axis=1)
    agg.columns=names
    # drop rows with Nan values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
Xy_train=gen_lag_features(train)
Xy_train
# Out:
#                      Junction 1 (H-1)  Junction 2 (H-1)  Junction 3 (H-1)  \
# DateTime
# 2015-11-01 01:00:00              15.0               6.0               9.0
# 2015-11-01 02:00:00              13.0               6.0               7.0
# 2015-11-01 03:00:00              10.0               5.0               5.0
# 2015-11-01 04:00:00               7.0               6.0               1.0
# 2015-11-01 05:00:00               9.0               7.0               2.0
# ...                               ...               ...               ...
# 2017-06-30 19:00:00              95.0              34.0              38.0
# 2017-06-30 20:00:00             105.0              34.0              33.0
# 2017-06-30 21:00:00              96.0              35.0              31.0
# 2017-06-30 22:00:00              90.0              31.0              28.0
# 2017-06-30 23:00:00              84.0              29.0              26.0
#
#                      Junction 4 (H-1)  Junction 1 (H)  Junction 2 (H)  \
# DateTime
# 2015-11-01 01:00:00               0.0              13               6
# 2015-11-01 02:00:00               0.0              10               5
# 2015-11-01 03:00:00               0.0               7               6
# 2015-11-01 04:00:00               0.0               9               7
# 2015-11-01 05:00:00               0.0               6               2
# ...                               ...             ...             ...
# 2017-06-30 19:00:00              17.0             105              34
# 2017-06-30 20:00:00              11.0              96              35
# 2017-06-30 21:00:00              30.0              90              31
# 2017-06-30 22:00:00              16.0              84              29
# 2017-06-30 23:00:00              22.0              78              27
#
#                      Junction 3 (H)  Junction 4 (H)
# DateTime
# 2015-11-01 01:00:00               7               0
# 2015-11-01 02:00:00               5               0
# 2015-11-01 03:00:00               1               0
# 2015-11-01 04:00:00               2               0
# 2015-11-01 05:00:00               2               0
# ...                             ...             ...
# 2017-06-30 19:00:00              33              11
# 2017-06-30 20:00:00              31              30
# 2017-06-30 21:00:00              28              16
# 2017-06-30 22:00:00              26              22
# 2017-06-30 23:00:00              39              12
#
# [14591 rows x 8 columns]

# %% [markdown]
# # MinMaxScaler - This package helps in shrinking the data within the given range

# %%
from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler(feature_range=(0,1))
Xy_train[Xy_train.columns] = scaler.fit_transform(Xy_train[Xy_train.columns])
Xy_train
# All data have been converted within the range of [0,1]
# Out:
#                      Junction 1 (H-1)  Junction 2 (H-1)  Junction 3 (H-1)  \
# DateTime
# 2015-11-01 01:00:00          0.066225          0.106383          0.044693
# 2015-11-01 02:00:00          0.052980          0.106383          0.033520
# 2015-11-01 03:00:00          0.033113          0.085106          0.022346
# 2015-11-01 04:00:00          0.013245          0.106383          0.000000
# 2015-11-01 05:00:00          0.026490          0.127660          0.005587
# ...                               ...               ...               ...
# 2017-06-30 19:00:00          0.596026          0.702128          0.206704
# 2017-06-30 20:00:00          0.662252          0.702128          0.178771
# 2017-06-30 21:00:00          0.602649          0.723404          0.167598
# 2017-06-30 22:00:00          0.562914          0.638298          0.150838
# 2017-06-30 23:00:00          0.523179          0.595745          0.139665
#
# 2017-01-31 23:00:00        0.463576        0.404255        0.067039
#
#                      Junction 4 (H)
# DateTime
# 2015-11-01 01:00:00        0.000000
# 2015-11-01 02:00:00        0.000000
# 2015-11-01 03:00:00        0.000000
# 2015-11-01 04:00:00        0.000000
# 2015-11-01 05:00:00        0.000000
# ...                             ...
# 2017-01-31 19:00:00        0.250000
# 2017-01-31 20:00:00        0.222222
# 2017-01-31 21:00:00        0.250000
# 2017-01-31 22:00:00        0.250000
# 2017-01-31 23:00:00        0.138889
#
# [10991 rows x 4 columns]

# %%
X_train=X_train.values
print(X_train.shape)

y_train=y_train.values
print(y_train.shape)
# Out:
# (10991, 4)
# (10991, 4)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.initializers import he_normal
import keras.backend as K

def root_mean_squared_error(y_true,y_pred):
    return K.sqrt(K.mean(K.square(y_pred-y_true),axis=-1))

# %%
#Initialising the RNN
regressor = Sequential()

#Adding the input layer and the LSTM layer
regressor.add(LSTM(units=50,activation='relu',kernel_initializer= he_normal(seed=0),input_shape=(None,1)))

#output for 4 junctions
regressor.add(Dense(units =4))

#compiling the RNN
regressor.compile(optimizer='adam',loss=root_mean_squared_error)

# %%
regressor.fit(X_train,y_train,batch_size=128,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 86/86 [==============================] - 2s 6ms/step - loss: 0.0566
# Epoch 2/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0369
# Epoch 3/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0347
# Epoch 4/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0333
# Epoch 5/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0322
# Epoch 6/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0314
# Epoch 7/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0307
# Epoch 8/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0304
# Epoch 9/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0302
# Epoch 10/100
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0301
# Epoch 11/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0301
# Epoch 12/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0300
# Epoch 13/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0300
# Epoch 14/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0299
# Epoch 15/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0298
# Epoch 16/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0298
# Epoch 17/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0297
# Epoch 18/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0297
# Epoch 19/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0297
# Epoch 20/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0296
# Epoch 21/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0297
# Epoch 22/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0297
# Epoch 23/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0297
# Epoch 24/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0296
# Epoch 25/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0296
# Epoch 26/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0296
# Epoch 27/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0295
# Epoch 28/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0296
# Epoch 29/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0296
# Epoch 30/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0295
# Epoch 31/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0295
# Epoch 32/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0295
# Epoch 33/100
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0294
# Epoch 34/100
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0295
# Epoch 35/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0294
# Epoch 36/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0295
# Epoch 37/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0294
# Epoch 38/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0295
# Epoch 39/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0295
# Epoch 40/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0293
# Epoch 41/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0293
# Epoch 42/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0293
# Epoch 43/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0295
# Epoch 44/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0294
# Epoch 45/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0293
# Epoch 46/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0293
# Epoch 47/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0293
# Epoch 48/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0293
# Epoch 49/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0292
# Epoch 50/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0293
# Epoch 51/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0293
# Epoch 52/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0293
# Epoch 53/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0293
# Epoch 54/100
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0294
# Epoch 55/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0293
# Epoch 56/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0292
# Epoch 57/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0292
# Epoch 58/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0293
# Epoch 59/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0292
# Epoch 60/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0292
# Epoch 61/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0293
# Epoch 62/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0292
# Epoch 63/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0292
# Epoch 64/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0291
# Epoch 65/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0292
# Epoch 66/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0292
# Epoch 67/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0292
# Epoch 68/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0292
# Epoch 69/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0292
# Epoch 70/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0292
# Epoch 71/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0292
# Epoch 72/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0291
# Epoch 73/100
# 86/86 [==============================] - 0s 6ms/step - loss: 0.0291
# Epoch 74/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0291
# Epoch 75/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0291
# Epoch 76/100
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0293
# Epoch 77/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0291
# Epoch 78/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0290
# Epoch 79/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0291
# Epoch 80/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0291
# Epoch 81/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0290
# Epoch 82/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0292
# Epoch 83/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0290
# Epoch 84/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0291
# Epoch 85/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0292
# Epoch 86/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0291
# Epoch 87/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0292
# Epoch 88/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0291
# Epoch 89/100
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0290
# Epoch 90/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0291
# Epoch 91/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0290
# Epoch 92/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0291
# Epoch 93/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0291
# Epoch 94/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0291
# Epoch 95/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0292
# Epoch 96/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0290
# Epoch 97/100
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0290
# Epoch 98/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0290
# Epoch 99/100
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0290
# Epoch 100/100
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0290

# %%
X_valid=Xy_train[Xy_train.index >='2017-02-01'].iloc[:,0:4]
X_valid
# Out:
#                      Junction 1 (H-1)  Junction 2 (H-1)  Junction 3 (H-1)  \
# DateTime
# 2017-02-01 00:00:00          0.463576          0.404255          0.067039
# 2017-02-01 01:00:00          0.423841          0.340426          0.083799
# 2017-02-01 02:00:00          0.364238          0.425532          0.044693
# 2017-02-01 03:00:00          0.344371          0.319149          0.044693
# 2017-02-01 04:00:00          0.284768          0.297872          0.055866
# ...                               ...               ...               ...
# 2017-06-30 19:00:00          0.596026          0.702128          0.206704
# 2017-06-30 20:00:00          0.662252          0.702128          0.178771
# 2017-06-30 21:00:00          0.602649          0.723404          0.167598
# 2017-06-30 22:00:00          0.562914          0.638298          0.150838
# 2017-06-30 23:00:00          0.523179          0.595745          0.139665
#
#                      Junction 4 (H-1)
# DateTime
# 2017-02-01 00:00:00          0.138889
# 2017-02-01 01:00:00          0.138889
# 2017-02-01 02:00:00          0.083333
# 2017-02-01 03:00:00          0.166667
# 2017-02-01 04:00:00          0.166667
# ...                               ...
# 2017-06-30 19:00:00          0.472222
# 2017-06-30 20:00:00          0.305556
# 2017-06-30 21:00:00          0.833333
# 2017-06-30 22:00:00          0.444444
# 2017-06-30 23:00:00          0.611111
#
# [3600 rows x 4 columns]

# %%
predictions = regressor.predict(X_valid)
predictions =scaler.inverse_transform(np.concatenate((X_valid.squeeze(),predictions),axis=1))[:,4:]
predictions
# Out:
# 113/113 [==============================] - 1s 3ms/step
# array([[70.94254848, 18.16733369, 14.34291547,  6.94613332],
#        [67.26517835, 16.28130543, 16.29029826,  7.10051322],
#        [56.18210825, 17.14269394, 11.22136175,  4.81140876],
#        ...,
#        [92.33743936, 31.02328461, 33.439318  , 18.21305323],
#        [82.28158265, 24.17119053, 25.86280337, 12.57455099],
#        [82.36634749, 25.03735405, 26.94610111, 14.01131165]])

# %%
y_test = train[train.index>='2017-02-01']
y_test
# Out:
# Junction             1.0  2.0  3.0  4.0
# DateTime
# 2017-02-01 00:00:00   69   17   16    5
# 2017-02-01 01:00:00   60   21    9    3
# 2017-02-01 02:00:00   57   16    9    6
# 2017-02-01 03:00:00   48   15   11    6
# 2017-02-01 04:00:00   45   15    5    2
# ...                  ...  ...  ...  ...
# 2017-06-30 19:00:00  105   34   33   11
# 2017-06-30 20:00:00   96   35   31   30
# 2017-06-30 21:00:00   90   31   28   16
# 2017-06-30 22:00:00   84   29   26   22
# 2017-06-30 23:00:00   78   27   39   12
#
# [3600 rows x 4 columns]

# %%
for junction in range(4):
    plt.figure
    plt.plot(y_test.values[:,junction],color ='blue',label='Real traffic')
    plt.plot(predictions[:,junction],color='yellow', label='Predicted traffic')
    plt.title('Traffic Forecasting at junction %i'%(junction+1))
    plt.xlabel('Number of hours from Start')
    plt.ylabel('Traffic')
    plt.legend()
    plt.show()

# %%
from sklearn import metrics
print('MAE: ',metrics.mean_absolute_error(y_test,predictions))
print('MSE: ',metrics.mean_squared_error(y_test,predictions))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# MAE:  4.377444501686323
# MSE:  43.86074127351941
# RMSE:  6.622744240382487
